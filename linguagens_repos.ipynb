# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get("https://api.github.com/events")
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
# status 
r.status_code
# Out:
# 200

# %%
# endereço url
r.url
# Out:
# 'https://api.github.com/events'

# %%
# conteudo da requisição
r.text
# Out:
# '[{"id":"33950267649","type":"PushEvent","actor":{"id":153060631,"login":"bessonetusdarwolves","display_login":"bessonetusdarwolves","gravatar_id":"","url":"https://api.github.com/users/bessonetusdarwolves","avatar_url":"https://avatars.githubusercontent.com/u/153060631?"},"repo":{"id":728063074,"name":"bessonetusdarwolves/Vape-V4-Cracked-by-dox","url":"https://api.github.com/repos/bessonetusdarwolves/Vape-V4-Cracked-by-dox"},"payload":{"repository_id":728063074,"push_id":16157309278,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"23d403b640ecd8d2c780c93c52994b746113cc6a","before":"4c618dfc13a2848efe3d8bd1e4e7d8723027f010","commits":[{"sha":"23d403b640ecd8d2c780c93c52994b746113cc6a","author":{"email":"153060631+bessonetusdarwolves@users.noreply.github.com","name":"bessonetusdarwolves"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/bessonetusdarwolves/Vape-V4-Cracked-by-dox/commits/23d403b640ecd8d2c780c93c52994b746113cc6a"}]},"public":true,"created_at":"2023-12-06T18:43:20Z"},{"id":"33950267635","type":"PushEvent","actor":{"id":153082257,"login":"gandisgejior1992","display_login":"gandisgejior1992","gravatar_id":"","url":"https://api.github.com/users/gandisgejior1992","avatar_url":"https://avatars.githubusercontent.com/u/153082257?"},"repo":{"id":728163591,"name":"gandisgejior1992/Overwatch-2-Hack-FREE","url":"https://api.github.com/repos/gandisgejior1992/Overwatch-2-Hack-FREE"},"payload":{"repository_id":728163591,"push_id":16157309255,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"97c28d88b5d8c2c729bd17f51079dca716d5a00a","before":"92a67af39673354904279c75731d81fb8e02050c","commits":[{"sha":"97c28d88b5d8c2c729bd17f51079dca716d5a00a","author":{"email":"153082257+gandisgejior1992@users.noreply.github.com","name":"gandisgejior1992"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/gandisgejior1992/Overwatch-2-Hack-FREE/commits/97c28d88b5d8c2c729bd17f51079dca716d5a00a"}]},"public":true,"created_at":"2023-12-06T18:43:20Z"},{"id":"33950267630","type":"PushEvent","actor":{"id":93980523,"login":"tantd21","display_login":"tantd21","gravatar_id":"","url":"https://api.github.com/users/tantd21","avatar_url":"https://avatars.githubusercontent.com/u/93980523?"},"repo":{"id":698331829,"name":"tantd21/SpringMVC","url":"https://api.github.com/repos/tantd21/SpringMVC"},"payload":{"repository_id":698331829,"push_id":16157309270,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"8806425a5f18812bb42be7e438e1b817330a3261","before":"b90ae1217a4e0830ef5fe4a56546f25bece804a6","commits":[{"sha":"8806425a5f18812bb42be7e438e1b817330a3261","author":{"email":"ta090707@gmail.com","name":"tantd21"},"message":"Order update","distinct":true,"url":"https://api.github.com/repos/tantd21/SpringMVC/commits/8806425a5f18812bb42be7e438e1b817330a3261"}]},"public":true,"created_at":"2023-12-06T18:43:20Z"},{"id":"33950267657","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":728346850,"name":"Kostafun/ChatGPT-Next-Web","url":"https://api.github.com/repos/Kostafun/ChatGPT-Next-Web"},"payload":{"ref":"dependabot/npm_and_yarn/eslint-8.55.0","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2023-12-06T18:43:20Z"},{"id":"33950267686","type":"PushEvent","actor":{"id":153057015,"login":"speargolden1992","display_login":"speargolden1992","gravatar_id":"","url":"https://api.github.com/users/speargolden1992","avatar_url":"https://avatars.githubusercontent.com/u/153057015?"},"repo":{"id":728046634,"name":"speargolden1992/hwid-spoofer","url":"https://api.github.com/repos/speargolden1992/hwid-spoofer"},"payload":{"repository_id":728046634,"push_id":16157309299,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"3b016f28a25 ...

# %%
# conteúdo da requisição pelo json
r.json()
# Out:
# [{'id': '33950267649',
#   'type': 'PushEvent',
#   'actor': {'id': 153060631,
#    'login': 'bessonetusdarwolves',
#    'display_login': 'bessonetusdarwolves',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bessonetusdarwolves',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153060631?'},
#   'repo': {'id': 728063074,
#    'name': 'bessonetusdarwolves/Vape-V4-Cracked-by-dox',
#    'url': 'https://api.github.com/repos/bessonetusdarwolves/Vape-V4-Cracked-by-dox'},
#   'payload': {'repository_id': 728063074,
#    'push_id': 16157309278,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '23d403b640ecd8d2c780c93c52994b746113cc6a',
#    'before': '4c618dfc13a2848efe3d8bd1e4e7d8723027f010',
#    'commits': [{'sha': '23d403b640ecd8d2c780c93c52994b746113cc6a',
#      'author': {'email': '153060631+bessonetusdarwolves@users.noreply.github.com',
#       'name': 'bessonetusdarwolves'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bessonetusdarwolves/Vape-V4-Cracked-by-dox/commits/23d403b640ecd8d2c780c93c52994b746113cc6a'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267635',
#   'type': 'PushEvent',
#   'actor': {'id': 153082257,
#    'login': 'gandisgejior1992',
#    'display_login': 'gandisgejior1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gandisgejior1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153082257?'},
#   'repo': {'id': 728163591,
#    'name': 'gandisgejior1992/Overwatch-2-Hack-FREE',
#    'url': 'https://api.github.com/repos/gandisgejior1992/Overwatch-2-Hack-FREE'},
#   'payload': {'repository_id': 728163591,
#    'push_id': 16157309255,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '97c28d88b5d8c2c729bd17f51079dca716d5a00a',
#    'before': '92a67af39673354904279c75731d81fb8e02050c',
#    'commits': [{'sha': '97c28d88b5d8c2c729bd17f51079dca716d5a00a',
#      'author': {'email': '153082257+gandisgejior1992@users.noreply.github.com',
#       'name': 'gandisgejior1992'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gandisgejior1992/Overwatch-2-Hack-FREE/commits/97c28d88b5d8c2c729bd17f51079dca716d5a00a'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267630',
#   'type': 'PushEvent',
#   'actor': {'id': 93980523,
#    'login': 'tantd21',
#    'display_login': 'tantd21',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tantd21',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93980523?'},
#   'repo': {'id': 698331829,
#    'name': 'tantd21/SpringMVC',
#    'url': 'https://api.github.com/repos/tantd21/SpringMVC'},
#   'payload': {'repository_id': 698331829,
#    'push_id': 16157309270,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8806425a5f18812bb42be7e438e1b817330a3261',
#    'before': 'b90ae1217a4e0830ef5fe4a56546f25bece804a6',
#    'commits': [{'sha': '8806425a5f18812bb42be7e438e1b817330a3261',
#      'author': {'email': 'ta090707@gmail.com', 'name': 'tantd21'},
#      'message': 'Order update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tantd21/SpringMVC/commits/8806425a5f18812bb42be7e438e1b817330a3261'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267657',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 728346850,
#    'name': 'Kostafun/ChatGPT-Next-Web',
#    'url': 'https://api.github.com/repos/Kostafun/ChatGPT-Next-Web'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/eslint-8.55.0',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267686',
#   'type': 'PushEvent',
#   'actor': {'id': 153057015,
#    'login': 'speargolden1992',
#    'display_login': 'speargolden1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/speargolden1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153057015?'},
#   'repo': {'id': 728046634,
#    'name': 'speargolden1992/hwid-spoofer',
#    'url': 'https://api.github.com/repos/speargolden1992/hwid-spoofer'},
#   'payload': {'repository_id': 728046634,
#    'push_id': 16157309299,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3b016f28a25d3206bff9b7e4d4eb64063ac40f7c',
#    'before': '31f475f3f713387f7560e250b73a4232d1f5ccc0',
#    'commits': [{'sha': '3b016f28a25d3206bff9b7e4d4eb64063ac40f7c',
#      'author': {'email': '153057015+speargolden1992@users.noreply.github.com',
#       'name': 'speargolden1992'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/speargolden1992/hwid-spoofer/commits/3b016f28a25d3206bff9b7e4d4eb64063ac40f7c'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267637',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 19603573,
#    'login': 'itsMapleLeaf',
#    'display_login': 'itsMapleLeaf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/itsMapleLeaf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19603573?'},
#   'repo': {'id': 680288824,
#    'name': 'itsMapleLeaf/game-of-arte',
#    'url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte'},
#   'payload': {'action': 'closed',
#    'number': 42,
#    'pull_request': {'url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/42',
#     'id': 1633060061,
#     'node_id': 'PR_kwDOKIxiOM5hVoTd',
#     'html_url': 'https://github.com/itsMapleLeaf/game-of-arte/pull/42',
#     'diff_url': 'https://github.com/itsMapleLeaf/game-of-arte/pull/42.diff',
#     'patch_url': 'https://github.com/itsMapleLeaf/game-of-arte/pull/42.patch',
#     'issue_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/42',
#     'number': 42,
#     'state': 'closed',
#     'locked': False,
#     'title': 'accessible name for attribute roll button',
#     'user': {'login': 'itsMapleLeaf',
#      'id': 19603573,
#      'node_id': 'MDQ6VXNlcjE5NjAzNTcz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19603573?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/itsMapleLeaf',
#      'html_url': 'https://github.com/itsMapleLeaf',
#      'followers_url': 'https://api.github.com/users/itsMapleLeaf/followers',
#      'following_url': 'https://api.github.com/users/itsMapleLeaf/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/itsMapleLeaf/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/itsMapleLeaf/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/itsMapleLeaf/subscriptions',
#      'organizations_url': 'https://api.github.com/users/itsMapleLeaf/orgs',
#      'repos_url': 'https://api.github.com/users/itsMapleLeaf/repos',
#      'events_url': 'https://api.github.com/users/itsMapleLeaf/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/itsMapleLeaf/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-12-06T18:40:39Z',
#     'updated_at': '2023-12-06T18:43:19Z',
#     'closed_at': '2023-12-06T18:43:19Z',
#     'merged_at': '2023-12-06T18:43:19Z',
#     'merge_commit_sha': '3d1e107d41e1c750a03ee5ae82b8e29db18d1ec0',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/42/commits',
#     'review_comments_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/42/comments',
#     'review_comment_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/42/comments',
#     'statuses_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/statuses/dac55b51006a76feb2b0e8af26e9106a7562a60a',
#     'head': {'label': 'itsMapleLeaf:12-06-accessible_name_for_attribute_roll_button',
#      'ref': '12-06-accessible_name_for_attribute_roll_button',
#      'sha': 'dac55b51006a76feb2b0e8af26e9106a7562a60a',
#      'user': {'login': 'itsMapleLeaf',
#       'id': 19603573,
#       'node_id': 'MDQ6VXNlcjE5NjAzNTcz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/19603573?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/itsMapleLeaf',
#       'html_url': 'https://github.com/itsMapleLeaf',
#       'followers_url': 'https://api.github.com/users/itsMapleLeaf/followers',
#       'following_url': 'https://api.github.com/users/itsMapleLeaf/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/itsMapleLeaf/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/itsMapleLeaf/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/itsMapleLeaf/subscriptions',
#       'organizations_url': 'https://api.github.com/users/itsMapleLeaf/orgs',
#       'repos_url': 'https://api.github.com/users/itsMapleLeaf/repos',
#       'events_url': 'https://api.github.com/users/itsMapleLeaf/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/itsMapleLeaf/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 680288824,
#       'node_id': 'R_kgDOKIxiOA',
#       'name': 'game-of-arte',
#       'full_name': 'itsMapleLeaf/game-of-arte',
#       'private': False,
#       'owner': {'login': 'itsMapleLeaf',
#        'id': 19603573,
#        'node_id': 'MDQ6VXNlcjE5NjAzNTcz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/19603573?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/itsMapleLeaf',
#        'html_url': 'https://github.com/itsMapleLeaf',
#        'followers_url': 'https://api.github.com/users/itsMapleLeaf/followers',
#        'following_url': 'https://api.github.com/users/itsMapleLeaf/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/itsMapleLeaf/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/itsMapleLeaf/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/itsMapleLeaf/subscriptions',
#        'organizations_url': 'https://api.github.com/users/itsMapleLeaf/orgs',
#        'repos_url': 'https://api.github.com/users/itsMapleLeaf/repos',
#        'events_url': 'https://api.github.com/users/itsMapleLeaf/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/itsMapleLeaf/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/itsMapleLeaf/game-of-arte',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte',
#       'forks_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/forks',
#       'keys_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/teams',
#       'hooks_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/hooks',
#       'issue_events_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/events',
#       'assignees_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/tags',
#       'blobs_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/languages',
#       'stargazers_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/stargazers',
#       'contributors_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/contributors',
#       'subscribers_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/subscribers',
#       'subscription_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/subscription',
#       'commits_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/merges',
#       'archive_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/downloads',
#       'issues_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/deployments',
#       'created_at': '2023-08-18T20:13:09Z',
#       'updated_at': '2023-12-01T17:21:44Z',
#       'pushed_at': '2023-12-06T18:43:19Z',
#       'git_url': 'git://github.com/itsMapleLeaf/game-of-arte.git',
#       'ssh_url': 'git@github.com:itsMapleLeaf/game-of-arte.git',
#       'clone_url': 'https://github.com/itsMapleLeaf/game-of-arte.git',
#       'svn_url': 'https://github.com/itsMapleLeaf/game-of-arte',
#       'homepage': 'https://arte.mapleleaf.dev',
#       'size': 1165,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'itsMapleLeaf:main',
#      'ref': 'main',
#      'sha': '8c78072d9c9424d2e3396ba6111b14967743e66f',
#      'user': {'login': 'itsMapleLeaf',
#       'id': 19603573,
#       'node_id': 'MDQ6VXNlcjE5NjAzNTcz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/19603573?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/itsMapleLeaf',
#       'html_url': 'https://github.com/itsMapleLeaf',
#       'followers_url': 'https://api.github.com/users/itsMapleLeaf/followers',
#       'following_url': 'https://api.github.com/users/itsMapleLeaf/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/itsMapleLeaf/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/itsMapleLeaf/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/itsMapleLeaf/subscriptions',
#       'organizations_url': 'https://api.github.com/users/itsMapleLeaf/orgs',
#       'repos_url': 'https://api.github.com/users/itsMapleLeaf/repos',
#       'events_url': 'https://api.github.com/users/itsMapleLeaf/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/itsMapleLeaf/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 680288824,
#       'node_id': 'R_kgDOKIxiOA',
#       'name': 'game-of-arte',
#       'full_name': 'itsMapleLeaf/game-of-arte',
#       'private': False,
#       'owner': {'login': 'itsMapleLeaf',
#        'id': 19603573,
#        'node_id': 'MDQ6VXNlcjE5NjAzNTcz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/19603573?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/itsMapleLeaf',
#        'html_url': 'https://github.com/itsMapleLeaf',
#        'followers_url': 'https://api.github.com/users/itsMapleLeaf/followers',
#        'following_url': 'https://api.github.com/users/itsMapleLeaf/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/itsMapleLeaf/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/itsMapleLeaf/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/itsMapleLeaf/subscriptions',
#        'organizations_url': 'https://api.github.com/users/itsMapleLeaf/orgs',
#        'repos_url': 'https://api.github.com/users/itsMapleLeaf/repos',
#        'events_url': 'https://api.github.com/users/itsMapleLeaf/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/itsMapleLeaf/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/itsMapleLeaf/game-of-arte',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte',
#       'forks_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/forks',
#       'keys_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/teams',
#       'hooks_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/hooks',
#       'issue_events_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/events',
#       'assignees_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/tags',
#       'blobs_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/languages',
#       'stargazers_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/stargazers',
#       'contributors_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/contributors',
#       'subscribers_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/subscribers',
#       'subscription_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/subscription',
#       'commits_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/merges',
#       'archive_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/downloads',
#       'issues_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/deployments',
#       'created_at': '2023-08-18T20:13:09Z',
#       'updated_at': '2023-12-01T17:21:44Z',
#       'pushed_at': '2023-12-06T18:43:19Z',
#       'git_url': 'git://github.com/itsMapleLeaf/game-of-arte.git',
#       'ssh_url': 'git@github.com:itsMapleLeaf/game-of-arte.git',
#       'clone_url': 'https://github.com/itsMapleLeaf/game-of-arte.git',
#       'svn_url': 'https://github.com/itsMapleLeaf/game-of-arte',
#       'homepage': 'https://arte.mapleleaf.dev',
#       'size': 1165,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/42'},
#      'html': {'href': 'https://github.com/itsMapleLeaf/game-of-arte/pull/42'},
#      'issue': {'href': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/42'},
#      'comments': {'href': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/issues/42/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/42/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/pulls/42/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/itsMapleLeaf/game-of-arte/statuses/dac55b51006a76feb2b0e8af26e9106a7562a60a'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'itsMapleLeaf',
#      'id': 19603573,
#      'node_id': 'MDQ6VXNlcjE5NjAzNTcz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19603573?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/itsMapleLeaf',
#      'html_url': 'https://github.com/itsMapleLeaf',
#      'followers_url': 'https://api.github.com/users/itsMapleLeaf/followers',
#      'following_url': 'https://api.github.com/users/itsMapleLeaf/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/itsMapleLeaf/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/itsMapleLeaf/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/itsMapleLeaf/subscriptions',
#      'organizations_url': 'https://api.github.com/users/itsMapleLeaf/orgs',
#      'repos_url': 'https://api.github.com/users/itsMapleLeaf/repos',
#      'events_url': 'https://api.github.com/users/itsMapleLeaf/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/itsMapleLeaf/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267612',
#   'type': 'PushEvent',
#   'actor': {'id': 153041111,
#    'login': 'glambitbaflocer',
#    'display_login': 'glambitbaflocer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/glambitbaflocer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153041111?'},
#   'repo': {'id': 727968969,
#    'name': 'glambitbaflocer/rust-hack',
#    'url': 'https://api.github.com/repos/glambitbaflocer/rust-hack'},
#   'payload': {'repository_id': 727968969,
#    'push_id': 16157309271,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0c34cbdeda4b735ee59bbdde30b5bffc7f419d4a',
#    'before': '503d85f7dca479c081e2b9dba45f45fcccc63f1c',
#    'commits': [{'sha': '0c34cbdeda4b735ee59bbdde30b5bffc7f419d4a',
#      'author': {'email': '153041111+glambitbaflocer@users.noreply.github.com',
#       'name': 'glambitbaflocer'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/glambitbaflocer/rust-hack/commits/0c34cbdeda4b735ee59bbdde30b5bffc7f419d4a'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267639',
#   'type': 'PushEvent',
#   'actor': {'id': 153098565,
#    'login': 'westilluminator70',
#    'display_login': 'westilluminator70',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/westilluminator70',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153098565?'},
#   'repo': {'id': 728241365,
#    'name': 'westilluminator70/hwid-spoofer',
#    'url': 'https://api.github.com/repos/westilluminator70/hwid-spoofer'},
#   'payload': {'repository_id': 728241365,
#    'push_id': 16157309283,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2432967a8db263e0e3edc0ff4ba67444103b752d',
#    'before': '341473bdc83d9381337c8d4e03d49ad13cb4f841',
#    'commits': [{'sha': '2432967a8db263e0e3edc0ff4ba67444103b752d',
#      'author': {'email': '153098565+westilluminator70@users.noreply.github.com',
#       'name': 'westilluminator70'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/westilluminator70/hwid-spoofer/commits/2432967a8db263e0e3edc0ff4ba67444103b752d'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267666',
#   'type': 'PushEvent',
#   'actor': {'id': 153059529,
#    'login': 'dirocconezameten59',
#    'display_login': 'dirocconezameten59',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dirocconezameten59',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153059529?'},
#   'repo': {'id': 728058631,
#    'name': 'dirocconezameten59/Rocket-League-Hack',
#    'url': 'https://api.github.com/repos/dirocconezameten59/Rocket-League-Hack'},
#   'payload': {'repository_id': 728058631,
#    'push_id': 16157309291,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '80387f0e13eac40ab6762235922b4cc07cc4fa7c',
#    'before': 'bffa449e1d94d511a685e5fedc7dc3e205ccea52',
#    'commits': [{'sha': '80387f0e13eac40ab6762235922b4cc07cc4fa7c',
#      'author': {'email': '153059529+dirocconezameten59@users.noreply.github.com',
#       'name': 'dirocconezameten59'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dirocconezameten59/Rocket-League-Hack/commits/80387f0e13eac40ab6762235922b4cc07cc4fa7c'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267660',
#   'type': 'PushEvent',
#   'actor': {'id': 152999934,
#    'login': 'sliperbenladen6',
#    'display_login': 'sliperbenladen6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sliperbenladen6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/152999934?'},
#   'repo': {'id': 727786783,
#    'name': 'sliperbenladen6/cs2-hack',
#    'url': 'https://api.github.com/repos/sliperbenladen6/cs2-hack'},
#   'payload': {'repository_id': 727786783,
#    'push_id': 16157309289,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c72be3d6c196e2b25ccaf5b13139a7c585755b5b',
#    'before': '41921ad7c33afdd4469f1f6b0f05d081deb02a5e',
#    'commits': [{'sha': 'c72be3d6c196e2b25ccaf5b13139a7c585755b5b',
#      'author': {'email': '152999934+sliperbenladen6@users.noreply.github.com',
#       'name': 'sliperbenladen6'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sliperbenladen6/cs2-hack/commits/c72be3d6c196e2b25ccaf5b13139a7c585755b5b'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267658',
#   'type': 'PushEvent',
#   'actor': {'id': 153096565,
#    'login': 'alpharampagestyle281',
#    'display_login': 'alpharampagestyle281',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alpharampagestyle281',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153096565?'},
#   'repo': {'id': 728232068,
#    'name': 'alpharampagestyle281/synapse-official',
#    'url': 'https://api.github.com/repos/alpharampagestyle281/synapse-official'},
#   'payload': {'repository_id': 728232068,
#    'push_id': 16157309281,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '590e987cd098d30aee5a4bcf00e2f80d34ae9d59',
#    'before': '2974c19ea1754501325f16cfa21dd34ebf4af405',
#    'commits': [{'sha': '590e987cd098d30aee5a4bcf00e2f80d34ae9d59',
#      'author': {'email': '153096565+alpharampagestyle281@users.noreply.github.com',
#       'name': 'alpharampagestyle281'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alpharampagestyle281/synapse-official/commits/590e987cd098d30aee5a4bcf00e2f80d34ae9d59'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267654',
#   'type': 'PushEvent',
#   'actor': {'id': 153064499,
#    'login': 'JavierMontenegro2109',
#    'display_login': 'JavierMontenegro2109',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JavierMontenegro2109',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153064499?'},
#   'repo': {'id': 728083687,
#    'name': 'JavierMontenegro2109/FnforcedFn1',
#    'url': 'https://api.github.com/repos/JavierMontenegro2109/FnforcedFn1'},
#   'payload': {'repository_id': 728083687,
#    'push_id': 16157309274,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'be813f91f241bd761b875c137c9189d4db59413f',
#    'before': '53e0a3a0f08f5aa98ad401222fb7f200b917448f',
#    'commits': [{'sha': 'be813f91f241bd761b875c137c9189d4db59413f',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JavierMontenegro2109/FnforcedFn1/commits/be813f91f241bd761b875c137c9189d4db59413f'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267577',
#   'type': 'PushEvent',
#   'actor': {'id': 153055848,
#    'login': 'infectedsquiltion',
#    'display_login': 'infectedsquiltion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infectedsquiltion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153055848?'},
#   'repo': {'id': 728040900,
#    'name': 'infectedsquiltion/Overwatch-2-Hack-FREE',
#    'url': 'https://api.github.com/repos/infectedsquiltion/Overwatch-2-Hack-FREE'},
#   'payload': {'repository_id': 728040900,
#    'push_id': 16157309237,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'abc1fc275b37729944c61dc9bfb9c1d8fb9ab71a',
#    'before': 'd40bd3917f5e8d16ece3b75cd9149b7d68aec28c',
#    'commits': [{'sha': 'abc1fc275b37729944c61dc9bfb9c1d8fb9ab71a',
#      'author': {'email': '153055848+infectedsquiltion@users.noreply.github.com',
#       'name': 'infectedsquiltion'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/infectedsquiltion/Overwatch-2-Hack-FREE/commits/abc1fc275b37729944c61dc9bfb9c1d8fb9ab71a'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267586',
#   'type': 'PushEvent',
#   'actor': {'id': 153056815,
#    'login': 'smoochiefezil306',
#    'display_login': 'smoochiefezil306',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smoochiefezil306',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153056815?'},
#   'repo': {'id': 728045545,
#    'name': 'smoochiefezil306/Vape-V4-Cracked-by-dox',
#    'url': 'https://api.github.com/repos/smoochiefezil306/Vape-V4-Cracked-by-dox'},
#   'payload': {'repository_id': 728045545,
#    'push_id': 16157309241,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bf1eec15a88ad4a10c317672284dd847c9043bfa',
#    'before': '93b928c5b3c2358b359944a6e948a8920deb71df',
#    'commits': [{'sha': 'bf1eec15a88ad4a10c317672284dd847c9043bfa',
#      'author': {'email': '153056815+smoochiefezil306@users.noreply.github.com',
#       'name': 'smoochiefezil306'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smoochiefezil306/Vape-V4-Cracked-by-dox/commits/bf1eec15a88ad4a10c317672284dd847c9043bfa'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267621',
#   'type': 'WatchEvent',
#   'actor': {'id': 8249379,
#    'login': 'froque',
#    'display_login': 'froque',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/froque',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8249379?'},
#   'repo': {'id': 58941978,
#    'name': 'froque/VSIXInteropFormsToolkit',
#    'url': 'https://api.github.com/repos/froque/VSIXInteropFormsToolkit'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267614',
#   'type': 'PushEvent',
#   'actor': {'id': 638536,
#    'login': 'HaronK',
#    'display_login': 'HaronK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HaronK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/638536?'},
#   'repo': {'id': 529162415,
#    'name': 'Limit-Theory-Redux/ltheory',
#    'url': 'https://api.github.com/repos/Limit-Theory-Redux/ltheory'},
#   'payload': {'repository_id': 529162415,
#    'push_id': 16157309250,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/haron/195-hmgui-implement-styling',
#    'head': '4fdb842dcd00ddd4dd05bb4b298a9271884d07d2',
#    'before': 'f53e960e06d5349454bc48945e3881b06331f72f',
#    'commits': [{'sha': '324bb2f1891b55406af5030f24155c709641a7f5',
#      'author': {'email': 'okreptul@yahoo.com', 'name': 'Oleg Khryptul'},
#      'message': 'Fix property registration methods',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Limit-Theory-Redux/ltheory/commits/324bb2f1891b55406af5030f24155c709641a7f5'},
#     {'sha': '573d3a89869dccca4946c7a8112b01a6671540e0',
#      'author': {'email': 'okreptul@yahoo.com', 'name': 'Oleg Khryptul'},
#      'message': 'Add code documentation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Limit-Theory-Redux/ltheory/commits/573d3a89869dccca4946c7a8112b01a6671540e0'},
#     {'sha': '4fdb842dcd00ddd4dd05bb4b298a9271884d07d2',
#      'author': {'email': 'okreptul@yahoo.com', 'name': 'Oleg Khryptul'},
#      'message': 'Update readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Limit-Theory-Redux/ltheory/commits/4fdb842dcd00ddd4dd05bb4b298a9271884d07d2'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z',
#   'org': {'id': 63032127,
#    'login': 'Limit-Theory-Redux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Limit-Theory-Redux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63032127?'}},
#  {'id': '33950267597',
#   'type': 'PushEvent',
#   'actor': {'id': 153058435,
#    'login': 'goofyifritik1992',
#    'display_login': 'goofyifritik1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/goofyifritik1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153058435?'},
#   'repo': {'id': 728053359,
#    'name': 'goofyifritik1992/Rust-Free-Hack',
#    'url': 'https://api.github.com/repos/goofyifritik1992/Rust-Free-Hack'},
#   'payload': {'repository_id': 728053359,
#    'push_id': 16157309259,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b61d2718536b6364cd39a32c3734cb243c459ecb',
#    'before': '7eadec3156d3cc2c83f0ddaf4bc8007d28dd00d1',
#    'commits': [{'sha': 'b61d2718536b6364cd39a32c3734cb243c459ecb',
#      'author': {'email': '153058435+goofyifritik1992@users.noreply.github.com',
#       'name': 'goofyifritik1992'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/goofyifritik1992/Rust-Free-Hack/commits/b61d2718536b6364cd39a32c3734cb243c459ecb'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267690',
#   'type': 'WatchEvent',
#   'actor': {'id': 153122964,
#    'login': 'ShoukhinKhan',
#    'display_login': 'ShoukhinKhan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShoukhinKhan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153122964?'},
#   'repo': {'id': 632796647,
#    'name': 'KawsarAhmad43/Carol42',
#    'url': 'https://api.github.com/repos/KawsarAhmad43/Carol42'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267647',
#   'type': 'PushEvent',
#   'actor': {'id': 153059349,
#    'login': 'mikimausbeaver0',
#    'display_login': 'mikimausbeaver0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mikimausbeaver0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153059349?'},
#   'repo': {'id': 728057916,
#    'name': 'mikimausbeaver0/Vape-V4-Cracked-by-dox',
#    'url': 'https://api.github.com/repos/mikimausbeaver0/Vape-V4-Cracked-by-dox'},
#   'payload': {'repository_id': 728057916,
#    'push_id': 16157309295,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6c00b9eabfdaf43db87e9e4f39b5a6b7e437c670',
#    'before': '7516db9ed53aaaa4a5699f6ac2bd15ef8b79d758',
#    'commits': [{'sha': '6c00b9eabfdaf43db87e9e4f39b5a6b7e437c670',
#      'author': {'email': '153059349+mikimausbeaver0@users.noreply.github.com',
#       'name': 'mikimausbeaver0'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mikimausbeaver0/Vape-V4-Cracked-by-dox/commits/6c00b9eabfdaf43db87e9e4f39b5a6b7e437c670'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267656',
#   'type': 'PushEvent',
#   'actor': {'id': 153060689,
#    'login': 'icelookvabum379',
#    'display_login': 'icelookvabum379',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/icelookvabum379',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153060689?'},
#   'repo': {'id': 728063479,
#    'name': 'icelookvabum379/Rust-Free-Hack',
#    'url': 'https://api.github.com/repos/icelookvabum379/Rust-Free-Hack'},
#   'payload': {'repository_id': 728063479,
#    'push_id': 16157309285,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7cf5898ee9b2f99f2f08f045742d8468acb3bf42',
#    'before': '60d4d0768881a6e2c7f6a353e57bfe1078647de5',
#    'commits': [{'sha': '7cf5898ee9b2f99f2f08f045742d8468acb3bf42',
#      'author': {'email': '153060689+icelookvabum379@users.noreply.github.com',
#       'name': 'icelookvabum379'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/icelookvabum379/Rust-Free-Hack/commits/7cf5898ee9b2f99f2f08f045742d8468acb3bf42'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267617',
#   'type': 'PushEvent',
#   'actor': {'id': 153064499,
#    'login': 'JavierMontenegro2109',
#    'display_login': 'JavierMontenegro2109',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JavierMontenegro2109',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153064499?'},
#   'repo': {'id': 728082861,
#    'name': 'JavierMontenegro2109/FnforcedFn7',
#    'url': 'https://api.github.com/repos/JavierMontenegro2109/FnforcedFn7'},
#   'payload': {'repository_id': 728082861,
#    'push_id': 16157309266,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '54fbff2e9b7f32ec7ddcb2516e13ac26074f5449',
#    'before': '6d7ed094015c6141b4a1abfe434a1cbb21bdf2d2',
#    'commits': [{'sha': '54fbff2e9b7f32ec7ddcb2516e13ac26074f5449',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JavierMontenegro2109/FnforcedFn7/commits/54fbff2e9b7f32ec7ddcb2516e13ac26074f5449'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267606',
#   'type': 'PushEvent',
#   'actor': {'id': 79866189,
#    'login': 'lmcelroy',
#    'display_login': 'lmcelroy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lmcelroy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79866189?'},
#   'repo': {'id': 728342258,
#    'name': 'lmcelroy/lmcelroy.github.io',
#    'url': 'https://api.github.com/repos/lmcelroy/lmcelroy.github.io'},
#   'payload': {'repository_id': 728342258,
#    'push_id': 16157309262,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a37946761be664e5d764558cc6f17e3aa3875201',
#    'before': '3a2ff001fa6209c4248b2aed630e379612615417',
#    'commits': [{'sha': 'a37946761be664e5d764558cc6f17e3aa3875201',
#      'author': {'email': '79866189+lmcelroy@users.noreply.github.com',
#       'name': 'lmcelroy'},
#      'message': 'Update _config.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lmcelroy/lmcelroy.github.io/commits/a37946761be664e5d764558cc6f17e3aa3875201'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267559',
#   'type': 'PushEvent',
#   'actor': {'id': 153042945,
#    'login': 'stne17johncastro',
#    'display_login': 'stne17johncastro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stne17johncastro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153042945?'},
#   'repo': {'id': 727978145,
#    'name': 'stne17johncastro/Vape-V4-Cracked-by-dox',
#    'url': 'https://api.github.com/repos/stne17johncastro/Vape-V4-Cracked-by-dox'},
#   'payload': {'repository_id': 727978145,
#    'push_id': 16157309239,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6257c2988ea48b039f21c4099c0426ec9dc5ae57',
#    'before': '8082f8b1ed97d2262d9e84d9443aa05dedcec1b0',
#    'commits': [{'sha': '6257c2988ea48b039f21c4099c0426ec9dc5ae57',
#      'author': {'email': '153042945+stne17johncastro@users.noreply.github.com',
#       'name': 'stne17johncastro'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/stne17johncastro/Vape-V4-Cracked-by-dox/commits/6257c2988ea48b039f21c4099c0426ec9dc5ae57'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267588',
#   'type': 'CreateEvent',
#   'actor': {'id': 24683184,
#    'login': 'imatiach-msft',
#    'display_login': 'imatiach-msft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/imatiach-msft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24683184?'},
#   'repo': {'id': 277645425,
#    'name': 'microsoft/responsible-ai-toolbox',
#    'url': 'https://api.github.com/repos/microsoft/responsible-ai-toolbox'},
#   'payload': {'ref': 'ilmat/treat-as-categorical-accessibility-fix',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Responsible AI Toolbox is a suite of tools providing model and data exploration and assessment user interfaces and libraries that enable a better understanding of AI systems. These interfaces and libraries empower developers and stakeholders of AI systems to develop and monitor AI more responsibly, and take better data-driven actions.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z',
#   'org': {'id': 6154722,
#    'login': 'microsoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/microsoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?'}},
#  {'id': '33950267578',
#   'type': 'PushEvent',
#   'actor': {'id': 153054903,
#    'login': 'poxmetologfreackinside1992',
#    'display_login': 'poxmetologfreackinside1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/poxmetologfreackinside1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153054903?'},
#   'repo': {'id': 728036282,
#    'name': 'poxmetologfreackinside1992/gta-v-mod-menu',
#    'url': 'https://api.github.com/repos/poxmetologfreackinside1992/gta-v-mod-menu'},
#   'payload': {'repository_id': 728036282,
#    'push_id': 16157309242,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '96dbd65ee7d8562d5ef21fb9d94f473ad26690ad',
#    'before': 'f1e694bd7d0d85e7c69324dbe8a4b06c08f07ded',
#    'commits': [{'sha': '96dbd65ee7d8562d5ef21fb9d94f473ad26690ad',
#      'author': {'email': '153054903+poxmetologfreackinside1992@users.noreply.github.com',
#       'name': 'poxmetologfreackinside1992'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/poxmetologfreackinside1992/gta-v-mod-menu/commits/96dbd65ee7d8562d5ef21fb9d94f473ad26690ad'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267604',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 398456137,
#    'name': 'rmdocs/AutoGreen',
#    'url': 'https://api.github.com/repos/rmdocs/AutoGreen'},
#   'payload': {'repository_id': 398456137,
#    'push_id': 16157309254,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3dcb5241205aa82c7f07e21c747108854b6a9df9',
#    'before': 'f1e55bbd6d68afe0c1323c066e3abb9514ef5215',
#    'commits': [{'sha': '3dcb5241205aa82c7f07e21c747108854b6a9df9',
#      'author': {'email': 'icbugcoder@88.com', 'name': 'rmdocs'},
#      'message': 'Keep writing documents now...',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rmdocs/AutoGreen/commits/3dcb5241205aa82c7f07e21c747108854b6a9df9'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267571',
#   'type': 'PushEvent',
#   'actor': {'id': 67113672,
#    'login': 'lorensansol',
#    'display_login': 'lorensansol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lorensansol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67113672?'},
#   'repo': {'id': 720894030,
#    'name': 'seacomoseo/moverepilatestraining.es',
#    'url': 'https://api.github.com/repos/seacomoseo/moverepilatestraining.es'},
#   'payload': {'repository_id': 720894030,
#    'push_id': 16157309225,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '27fbe847ecc1a0c11b74a0d44a1833fba7c8905a',
#    'before': 'edbae73bc077a7c0874b126440c8635cd6e228b0',
#    'commits': [{'sha': '27fbe847ecc1a0c11b74a0d44a1833fba7c8905a',
#      'author': {'email': 'lorensansol@gmail.com', 'name': 'lorensansol'},
#      'message': 'Update: 2023-12-06 19:43:18',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/seacomoseo/moverepilatestraining.es/commits/27fbe847ecc1a0c11b74a0d44a1833fba7c8905a'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z',
#   'org': {'id': 150803612,
#    'login': 'seacomoseo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/seacomoseo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/150803612?'}},
#  {'id': '33950267552',
#   'type': 'PushEvent',
#   'actor': {'id': 153053582,
#    'login': 'daggeridoiwant142',
#    'display_login': 'daggeridoiwant142',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daggeridoiwant142',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153053582?'},
#   'repo': {'id': 728029809,
#    'name': 'daggeridoiwant142/World-of-Warcraft-Multi-Bot',
#    'url': 'https://api.github.com/repos/daggeridoiwant142/World-of-Warcraft-Multi-Bot'},
#   'payload': {'repository_id': 728029809,
#    'push_id': 16157309217,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '09c696b640899e66aefdc709f356cb43e4ec591f',
#    'before': '06ef21a11e579d74d7217e1ae3955ab360a1ff58',
#    'commits': [{'sha': '09c696b640899e66aefdc709f356cb43e4ec591f',
#      'author': {'email': '153053582+daggeridoiwant142@users.noreply.github.com',
#       'name': 'daggeridoiwant142'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/daggeridoiwant142/World-of-Warcraft-Multi-Bot/commits/09c696b640899e66aefdc709f356cb43e4ec591f'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267605',
#   'type': 'CreateEvent',
#   'actor': {'id': 153122756,
#    'login': 'jianellee',
#    'display_login': 'jianellee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jianellee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153122756?'},
#   'repo': {'id': 728347696,
#    'name': 'jianellee/ims.io',
#    'url': 'https://api.github.com/repos/jianellee/ims.io'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'},
#  {'id': '33950267561',
#   'type': 'PushEvent',
#   'actor': {'id': 153064499,
#    'login': 'JavierMontenegro2109',
#    'display_login': 'JavierMontenegro2109',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JavierMontenegro2109',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153064499?'},
#   'repo': {'id': 728083660,
#    'name': 'JavierMontenegro2109/FnforcedFn4',
#    'url': 'https://api.github.com/repos/JavierMontenegro2109/FnforcedFn4'},
#   'payload': {'repository_id': 728083660,
#    'push_id': 16157309224,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6ae7be7861e799c9f0ef28d4243fbea4e96cac6d',
#    'before': '0123226e8227c0b1a01e5edc031fdfb7046b4054',
#    'commits': [{'sha': '6ae7be7861e799c9f0ef28d4243fbea4e96cac6d',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JavierMontenegro2109/FnforcedFn4/commits/6ae7be7861e799c9f0ef28d4243fbea4e96cac6d'}]},
#   'public': True,
#   'created_at': '2023-12-06T18:43:20Z'}]

# %% [markdown]
# ### Utilizando outro endpoint

# %%
r = requests.get("https://api.github.com/versions")
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']
